# %%
import numpy as np
import matplotlib.pyplot as plt
time_interval=np.arange(0,4,0.1)

# %%
def calculate_result(t):
    temp=(np.exp(-3*t/2)+np.exp(-2*t)-np.exp(-5*t/2))+np.exp(-5*t/6)+np.exp(-3*t)-np.exp(-23*t/6)-np.exp(-11*t/6)-np.exp(-4*t)+np.exp(-29*t/6)
    return temp

# %%
results=[]
for i in time_interval:
    results.append(calculate_result(i))
results_arranged=np.array(results)

# %%
plt.plot(time_interval,results_arranged,lw=2)
plt.xlabel('Time')
plt.ylabel('The probability')
axes = plt.gca()
# axes.set_ylim([0,1])

plt.show()
